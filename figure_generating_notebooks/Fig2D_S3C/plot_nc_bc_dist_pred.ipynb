# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['pdf.fonttype'] = 42

# %%
nc_bc_mod = pd.read_csv("nc_barcoded_detection_obs_pred_mod.csv")

# %%
nc_bc_mod
# Out:
#       nc_counts     CGd     ρ₃₁  ρ₄₁      ρ₃₂  ρ₄₂    predicted
# 0            92  366999   110.0  0.0    369.0  0.0   169.604450
# 1           494  575824  6299.0  0.0  23628.0  0.0   983.031020
# 2           192  459256   281.0  0.0    877.0  0.0   271.651239
# 3           496  489483  1203.0  0.0   4202.0  0.0   421.801643
# 4           162  444797     0.0  0.0      0.0  0.0   194.052094
# ...         ...     ...     ...  ...      ...  ...          ...
# 1824         60  275943   114.0  0.0    430.0  0.0   106.455189
# 1825        431  527899  5300.0  0.0  18220.0  0.0  1191.717352
# 1826         67  242590   376.0  0.0   1393.0  0.0   120.465995
# 1827        158  361302   523.0  0.0   2020.0  0.0   191.425673
# 1828        140  303168    94.0  0.0    371.0  0.0   116.939586
#
# [1829 rows x 7 columns]

# %%
plt.plot(nc_bc_mod['nc_counts'], nc_bc_mod['predicted'], '.', markersize=1, label=r"Negative control codeword (model $R^2 =0.51$)")
plt.legend()
plt.xlabel("Observed # of decoded barcodes")
plt.ylabel("Predicted # of decoded barcodes")
plt.xticks([100, 300, 500, 700, 900, 1100, 1300], minor=True)
plt.yticks([100, 300, 500, 700, 900, 1100, 1300], minor=True)
plt.savefig("SFIG3C_nc_bc_dist_mod.pdf")
